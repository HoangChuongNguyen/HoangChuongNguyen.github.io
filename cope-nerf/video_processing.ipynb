# %%
import os
import subprocess

def reencode_to_h264(directory):
    """
    Recursively walk `directory`, find all .mp4 files,
    re-encode each to H.264/AAC, and overwrite the original file.
    """
    for root, _, files in os.walk(directory):
        for fname in files:
            if not fname.lower().endswith('.mp4'):
                continue

            input_path = os.path.join(root, fname)
            tmp_path = input_path + '.tmp.mp4'

            # FFmpeg command: overwrite tmp if exists (-y)
            cmd = [
                'ffmpeg',
                '-y',                  # overwrite output without asking
                '-i', input_path,      # input file
                '-c:v', 'libx264',     # video codec
                '-preset', 'medium',   # encoding speed/quality
                '-crf', '23',          # quality
                '-c:a', 'aac',         # audio codec
                '-b:a', '128k',        # audio bitrate
                '-movflags', '+faststart',  # web optimization
                tmp_path               # temp output
            ]

            print(f"Re-encoding: {input_path}")
            try:
                subprocess.run(cmd, check=True)
                # Replace original with the new file
                os.replace(tmp_path, input_path)
                print(f"Overwritten: {input_path}")
            except subprocess.CalledProcessError as e:
                print(f"Error encoding {input_path}: {e}")
                # Clean up tmp if it exists
                if os.path.exists(tmp_path):
                    os.remove(tmp_path)

# Example usage in a Jupyter notebook cell:
reencode_to_h264('/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs')
# Out:
# Re-encoding: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Barn.mp4
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Barn.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 25837 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], 25834 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Barn.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f033aa3300] using SAR=1/1
# [libx264 @ 0x55f033aa3300] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f033aa3300] profile High, level 5.0
# [libx264 @ 0x55f033aa3300] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=40 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Barn.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x55f033aa51c0] Starting second pass: moving the moov atom to the beginning of the filex
# frame=  120 fps= 62 q=-1.0 Lsize=    4715kB time=00:00:03.90 bitrate=9903.6kbits/s speed=2.01x
# video:4713kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.034415%
# [libx264 @ 0x55f033aa3300] frame I:1     Avg QP:21.27  size:107636
# [libx264 @ 0x55f033aa3300] frame P:108   Avg QP:22.16  size: 42122
# [libx264 @ 0x55f033aa3300] frame B:11    Avg QP:23.93  size: 15354
# [libx264 @ 0x55f033aa3300] consecutive B-frames: 81.7% 18.3%  0.0%  0.0%
# [libx264 @ 0x55f033aa3300] mb I  I16..4: 47.8% 48.9%  3.4%
# [libx264 @ 0x55f033aa3300] mb P  I16..4:  2.1%  6.5%  0.1%  P16..4: 36.8%  7.8%  4.1%  0.0%  0.0%    skip:42.6%
# [libx264 @ 0x55f033aa3300] mb B  I16..4:  0.6%  1.6%  0.0%  B16..8: 34.9%  2.6%  0.3%  direct: 1.4%  skip:58.6%  L0:59.4% L1:30.3% BI:10.3%
# [libx264 @ 0x55f033aa3300] 8x8 transform intra:72.0% inter:78.9%
# [libx264 @ 0x55f033aa3300] coded y,uvDC,uvAC intra: 34.0% 46.5% 8.3% inter: 14.3% 13.0% 1.1%
# [libx264 @ 0x55f033aa3300] i16 v,h,dc,p: 35% 43% 13%  9%
# [libx264 @ 0x55f033aa3300] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 30% 43%  2%  1%  0%  1%  1%  2%
# [libx264 @ 0x55f033aa3300] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 28% 19%  3%  3%  3%  5%  3%  3%
# [libx264 @ 0x55f033aa3300] i8c dc,h,v,p: 43% 34% 19%  4%
# [libx264 @ 0x55f033aa3300] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55f033aa3300] ref P L0: 75.4% 13.2%  8.9%  2.5%
# [libx264 @ 0x55f033aa3300] ref B L0: 88.4% 11.6%
# [libx264 @ 0x55f033aa3300] kb/s:9651.46
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Ballroom.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 44413 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], 44409 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Ballroom.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Barn.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Ballroom.mp4
# [libx264 @ 0x55db710c4440] using SAR=1/1
# [libx264 @ 0x55db710c4440] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55db710c4440] profile High, level 5.0
# [libx264 @ 0x55db710c4440] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=40 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Ballroom.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x55db710c4e80] Starting second pass: moving the moov atom to the beginning of the filex
# frame=  120 fps= 66 q=-1.0 Lsize=    5628kB time=00:00:03.90 bitrate=11821.9kbits/s speed=2.14x
# video:5626kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.037024%
# [libx264 @ 0x55db710c4440] frame I:1     Avg QP:24.34  size:192234
# [libx264 @ 0x55db710c4440] frame P:58    Avg QP:22.74  size: 81356
# [libx264 @ 0x55db710c4440] frame B:61    Avg QP:26.24  size: 13927
# [libx264 @ 0x55db710c4440] consecutive B-frames: 30.8%  3.3%  2.5% 63.3%
# [libx264 @ 0x55db710c4440] mb I  I16..4: 31.9% 63.7%  4.4%
# [libx264 @ 0x55db710c4440] mb P  I16..4:  2.2%  4.1%  0.2%  P16..4: 35.9% 16.1%  9.3%  0.0%  0.0%    skip:32.3%
# [libx264 @ 0x55db710c4440] mb B  I16..4:  0.2%  0.6%  0.0%  B16..8: 37.0%  2.9%  0.4%  direct: 0.7%  skip:58.1%  L0:39.7% L1:47.3% BI:13.0%
# [libx264 @ 0x55db710c4440] 8x8 transform intra:63.7% inter:74.9%
# [libx264 @ 0x55db710c4440] coded y,uvDC,uvAC intra: 33.9% 53.6% 12.4% inter: 16.2% 14.2% 1.7%
# [libx264 @ 0x55db710c4440] i16 v,h,dc,p: 46% 33%  8% 13%
# [libx264 @ 0x55db710c4440] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 23% 38%  2%  1%  1%  2%  1%  2%
# [libx264 @ 0x55db710c4440] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 37% 16%  2%  4%  3%  5%  2%  4%
# [libx264 @ 0x55db710c4440] i8c dc,h,v,p: 36% 29% 29%  6%
# [libx264 @ 0x55db710c4440] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55db710c4440] ref P L0: 68.1% 18.4% 10.8%  2.7%
# [libx264 @ 0x55db710c4440] ref B L0: 92.5%  6.3%  1.2%
# [libx264 @ 0x55db710c4440] ref B L1: 97.2%  2.8%
# [libx264 @ 0x55db710c4440] kb/s:11520.86
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Francis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 24659 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], 24656 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Francis.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Ballroom.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Francis.mp4
# [libx264 @ 0x5630a79862c0] using SAR=1/1
# [libx264 @ 0x5630a79862c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5630a79862c0] profile High, level 5.0
# [libx264 @ 0x5630a79862c0] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=40 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Francis.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x5630a7988180] Starting second pass: moving the moov atom to the beginning of the filex
# frame=  120 fps= 60 q=-1.0 Lsize=    4644kB time=00:00:03.90 bitrate=9754.7kbits/s speed=1.95x
# video:4642kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.033846%
# [libx264 @ 0x5630a79862c0] frame I:1     Avg QP:23.27  size:137454
# [libx264 @ 0x5630a79862c0] frame P:110   Avg QP:22.07  size: 40941
# [libx264 @ 0x5630a79862c0] frame B:9     Avg QP:24.29  size: 12470
# [libx264 @ 0x5630a79862c0] consecutive B-frames: 85.0% 15.0%  0.0%  0.0%
# [libx264 @ 0x5630a79862c0] mb I  I16..4: 42.5% 53.6%  3.9%
# [libx264 @ 0x5630a79862c0] mb P  I16..4:  2.6%  7.1%  0.1%  P16..4: 39.9%  7.0%  3.7%  0.0%  0.0%    skip:39.6%
# [libx264 @ 0x5630a79862c0] mb B  I16..4:  0.5%  1.2%  0.0%  B16..8: 34.6%  1.9%  0.2%  direct: 0.7%  skip:60.9%  L0:61.6% L1:30.5% BI: 7.8%
# [libx264 @ 0x5630a79862c0] 8x8 transform intra:70.4% inter:79.4%
# [libx264 @ 0x5630a79862c0] coded y,uvDC,uvAC intra: 34.6% 44.8% 7.8% inter: 14.0% 14.7% 2.4%
# [libx264 @ 0x5630a79862c0] i16 v,h,dc,p: 30% 47% 15%  8%
# [libx264 @ 0x5630a79862c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 32% 43%  1%  1%  0%  1%  1%  2%
# [libx264 @ 0x5630a79862c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 31% 18%  2%  3%  2%  3%  2%  3%
# [libx264 @ 0x5630a79862c0] i8c dc,h,v,p: 46% 34% 17%  3%
# [libx264 @ 0x5630a79862c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5630a79862c0] ref P L0: 73.8% 15.3%  8.6%  2.3%
# [libx264 @ 0x5630a79862c0] ref B L0: 89.0% 11.0%
# [libx264 @ 0x5630a79862c0] kb/s:9506.44
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Museum.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 34663 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], 34660 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Museum.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55775aeffa00] using SAR=1/1
# [libx264 @ 0x55775aeffa00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# Overwritten: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Francis.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Museum.mp4
# [libx264 @ 0x55775aeffa00] profile High, level 5.0
# [libx264 @ 0x55775aeffa00] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=40 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Museum.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x55775af018c0] Starting second pass: moving the moov atom to the beginning of the filex
# frame=  120 fps= 61 q=-1.0 Lsize=    5820kB time=00:00:03.90 bitrate=12225.7kbits/s speed=1.97x
# video:5819kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.027071%
# [libx264 @ 0x55775aeffa00] frame I:1     Avg QP:23.35  size:183246
# [libx264 @ 0x55775aeffa00] frame P:110   Avg QP:22.70  size: 51543
# [libx264 @ 0x55775aeffa00] frame B:9     Avg QP:25.85  size: 11651
# [libx264 @ 0x55775aeffa00] consecutive B-frames: 85.0% 15.0%  0.0%  0.0%
# [libx264 @ 0x55775aeffa00] mb I  I16..4: 31.8% 64.0%  4.2%
# [libx264 @ 0x55775aeffa00] mb P  I16..4:  1.5%  4.3%  0.1%  P16..4: 42.3% 10.4%  5.5%  0.0%  0.0%    skip:35.9%
# [libx264 @ 0x55775aeffa00] mb B  I16..4:  0.4%  0.6%  0.0%  B16..8: 33.6%  1.9%  0.2%  direct: 0.5%  skip:62.8%  L0:51.0% L1:35.4% BI:13.6%
# [libx264 @ 0x55775aeffa00] 8x8 transform intra:71.2% inter:77.8%
# [libx264 @ 0x55775aeffa00] coded y,uvDC,uvAC intra: 41.4% 61.7% 17.1% inter: 20.0% 23.7% 3.3%
# [libx264 @ 0x55775aeffa00] i16 v,h,dc,p: 53% 25% 14%  8%
# [libx264 @ 0x55775aeffa00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 25% 40%  1%  1%  1%  2%  1%  2%
# [libx264 @ 0x55775aeffa00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37% 31% 17%  2%  3%  2%  3%  2%  3%
# [libx264 @ 0x55775aeffa00] i8c dc,h,v,p: 39% 25% 29%  6%
# [libx264 @ 0x55775aeffa00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55775aeffa00] ref P L0: 70.5% 19.7%  7.6%  2.1%
# [libx264 @ 0x55775aeffa00] ref B L0: 89.8% 10.2%
# [libx264 @ 0x55775aeffa00] kb/s:11915.60
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Horse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 31464 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], 31461 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Horse.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Museum.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Horse.mp4
# [libx264 @ 0x563264b8da00] using SAR=1/1
# [libx264 @ 0x563264b8da00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x563264b8da00] profile High, level 5.0
# [libx264 @ 0x563264b8da00] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=40 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Horse.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x563264b8f8c0] Starting second pass: moving the moov atom to the beginning of the filex
# frame=  120 fps= 63 q=-1.0 Lsize=    5226kB time=00:00:03.90 bitrate=10978.1kbits/s speed=2.06x
# video:5225kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.030821%
# [libx264 @ 0x563264b8da00] frame I:1     Avg QP:22.38  size:163795
# [libx264 @ 0x563264b8da00] frame P:105   Avg QP:22.08  size: 48002
# [libx264 @ 0x563264b8da00] frame B:14    Avg QP:24.63  size: 10402
# [libx264 @ 0x563264b8da00] consecutive B-frames: 80.0% 10.0% 10.0%  0.0%
# [libx264 @ 0x563264b8da00] mb I  I16..4: 39.2% 56.8%  4.1%
# [libx264 @ 0x563264b8da00] mb P  I16..4:  1.6%  3.8%  0.1%  P16..4: 35.6%  9.3%  5.4%  0.0%  0.0%    skip:44.2%
# [libx264 @ 0x563264b8da00] mb B  I16..4:  0.6%  1.1%  0.0%  B16..8: 29.2%  1.9%  0.3%  direct: 1.2%  skip:65.8%  L0:44.0% L1:45.3% BI:10.7%
# [libx264 @ 0x563264b8da00] 8x8 transform intra:67.5% inter:75.3%
# [libx264 @ 0x563264b8da00] coded y,uvDC,uvAC intra: 29.9% 54.0% 11.6% inter: 16.3% 19.8% 3.6%
# [libx264 @ 0x563264b8da00] i16 v,h,dc,p: 27% 50% 10% 13%
# [libx264 @ 0x563264b8da00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 27% 50%  1%  1%  1%  1%  1%  2%
# [libx264 @ 0x563264b8da00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37% 25% 18%  3%  4%  3%  4%  3%  3%
# [libx264 @ 0x563264b8da00] i8c dc,h,v,p: 37% 41% 16%  5%
# [libx264 @ 0x563264b8da00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x563264b8da00] ref P L0: 72.1% 17.4%  8.1%  2.4%
# [libx264 @ 0x563264b8da00] ref B L0: 88.5% 10.5%  1.0%
# [libx264 @ 0x563264b8da00] kb/s:10699.16
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Family.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 31642 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], 31639 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Family.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Horse.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Family.mp4
# [libx264 @ 0x55c95d6e4a00] using SAR=1/1
# [libx264 @ 0x55c95d6e4a00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55c95d6e4a00] profile High, level 5.0
# [libx264 @ 0x55c95d6e4a00] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=40 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Family.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x55c95d6e68c0] Starting second pass: moving the moov atom to the beginning of the filex
# frame=  120 fps= 65 q=-1.0 Lsize=    4801kB time=00:00:03.90 bitrate=10084.5kbits/s speed= 2.1x
# video:4799kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.039660%
# [libx264 @ 0x55c95d6e4a00] frame I:1     Avg QP:22.20  size:145672
# [libx264 @ 0x55c95d6e4a00] frame P:80    Avg QP:21.93  size: 53321
# [libx264 @ 0x55c95d6e4a00] frame B:39    Avg QP:24.78  size: 12878
# [libx264 @ 0x55c95d6e4a00] consecutive B-frames: 52.5% 11.7%  2.5% 33.3%
# [libx264 @ 0x55c95d6e4a00] mb I  I16..4: 39.1% 56.8%  4.1%
# [libx264 @ 0x55c95d6e4a00] mb P  I16..4:  1.7%  4.3%  0.1%  P16..4: 38.6% 10.6%  6.2%  0.0%  0.0%    skip:38.5%
# [libx264 @ 0x55c95d6e4a00] mb B  I16..4:  0.4%  1.5%  0.0%  B16..8: 35.2%  2.7%  0.4%  direct: 0.7%  skip:59.1%  L0:42.2% L1:49.6% BI: 8.2%
# [libx264 @ 0x55c95d6e4a00] 8x8 transform intra:68.9% inter:76.3%
# [libx264 @ 0x55c95d6e4a00] coded y,uvDC,uvAC intra: 32.9% 54.1% 9.2% inter: 14.0% 14.9% 1.8%
# [libx264 @ 0x55c95d6e4a00] i16 v,h,dc,p: 29% 44% 14% 12%
# [libx264 @ 0x55c95d6e4a00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 26% 47%  2%  1%  1%  1%  1%  2%
# [libx264 @ 0x55c95d6e4a00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 38% 23% 18%  3%  4%  4%  4%  3%  3%
# [libx264 @ 0x55c95d6e4a00] i8c dc,h,v,p: 42% 35% 18%  4%
# [libx264 @ 0x55c95d6e4a00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55c95d6e4a00] ref P L0: 69.9% 15.9% 10.9%  3.3%
# [libx264 @ 0x55c95d6e4a00] ref B L0: 91.5%  7.0%  1.5%
# [libx264 @ 0x55c95d6e4a00] ref B L1: 98.3%  1.7%
# [libx264 @ 0x55c95d6e4a00] kb/s:9827.25
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Ignatius.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 40425 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], 40422 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Ignatius.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Family.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Ignatius.mp4
# [libx264 @ 0x563be17f0d40] using SAR=1/1
# [libx264 @ 0x563be17f0d40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x563be17f0d40] profile High, level 5.0
# [libx264 @ 0x563be17f0d40] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=40 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Ignatius.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x563be17f2c00] Starting second pass: moving the moov atom to the beginning of the filex
# frame=  120 fps= 60 q=-1.0 Lsize=    6634kB time=00:00:03.90 bitrate=13934.1kbits/s speed=1.94x
# video:6632kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.024693%
# [libx264 @ 0x563be17f0d40] frame I:1     Avg QP:23.27  size:180776
# [libx264 @ 0x563be17f0d40] frame P:103   Avg QP:22.40  size: 62102
# [libx264 @ 0x563be17f0d40] frame B:16    Avg QP:25.40  size: 13331
# [libx264 @ 0x563be17f0d40] consecutive B-frames: 78.3%  6.7% 15.0%  0.0%
# [libx264 @ 0x563be17f0d40] mb I  I16..4: 31.6% 64.4%  4.0%
# [libx264 @ 0x563be17f0d40] mb P  I16..4:  1.3%  3.3%  0.1%  P16..4: 39.6% 12.0%  7.2%  0.0%  0.0%    skip:36.6%
# [libx264 @ 0x563be17f0d40] mb B  I16..4:  0.8%  2.0%  0.0%  B16..8: 34.4%  2.3%  0.4%  direct: 0.6%  skip:59.5%  L0:39.9% L1:48.6% BI:11.5%
# [libx264 @ 0x563be17f0d40] 8x8 transform intra:69.2% inter:75.3%
# [libx264 @ 0x563be17f0d40] coded y,uvDC,uvAC intra: 34.6% 53.4% 8.9% inter: 20.6% 19.0% 2.4%
# [libx264 @ 0x563be17f0d40] i16 v,h,dc,p: 18% 56% 13% 12%
# [libx264 @ 0x563be17f0d40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 29% 49%  2%  1%  1%  2%  1%  3%
# [libx264 @ 0x563be17f0d40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 31% 22%  3%  4%  3%  4%  3%  4%
# [libx264 @ 0x563be17f0d40] i8c dc,h,v,p: 40% 44% 12%  4%
# [libx264 @ 0x563be17f0d40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x563be17f0d40] ref P L0: 72.5% 19.2%  6.5%  1.8%
# [libx264 @ 0x563be17f0d40] ref B L0: 90.8%  7.9%  1.3%
# [libx264 @ 0x563be17f0d40] kb/s:13581.20
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Church.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 37595 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], 37591 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Church.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Ignatius.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Church.mp4
# [libx264 @ 0x55ba50d60c00] using SAR=1/1
# [libx264 @ 0x55ba50d60c00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ba50d60c00] profile High, level 5.0
# [libx264 @ 0x55ba50d60c00] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=40 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Church.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=   91 fps= 90 q=29.0 size=     512kB time=00:00:00.13 bitrate=31444.9kbits/s speed=0.132x
# Overwritten: /home/hoangchuongnguyen/Desktop/HoangChuongNguyen.github.io/cope-nerf/my_videos/nvs/Church.mp4
# [mp4 @ 0x55ba50d62ac0] Starting second pass: moving the moov atom to the beginning of the file
# frame=  120 fps= 56 q=-1.0 Lsize=    6508kB time=00:00:03.90 bitrate=13669.3kbits/s speed=1.82x
# video:6506kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.024811%
# [libx264 @ 0x55ba50d60c00] frame I:1     Avg QP:23.63  size:149315
# [libx264 @ 0x55ba50d60c00] frame P:108   Avg QP:22.78  size: 58596
# [libx264 @ 0x55ba50d60c00] frame B:11    Avg QP:25.45  size: 16717
# [libx264 @ 0x55ba50d60c00] consecutive B-frames: 83.3% 11.7%  5.0%  0.0%
# [libx264 @ 0x55ba50d60c00] mb I  I16..4: 38.9% 57.2%  3.9%
# [libx264 @ 0x55ba50d60c00] mb P  I16..4:  1.7%  5.3%  0.2%  P16..4: 43.1% 10.8%  5.6%  0.0%  0.0%    skip:33.3%
# [libx264 @ 0x55ba50d60c00] mb B  I16..4:  0.6%  1.4%  0.0%  B16..8: 34.5%  3.0%  0.4%  direct: 1.1%  skip:59.1%  L0:48.0% L1:34.7% BI:17.3%
# [libx264 @ 0x55ba50d60c00] 8x8 transform intra:71.9% inter:77.4%
# [libx264 @ 0x55ba50d60c00] coded y,uvDC,uvAC intra: 45.8% 66.8% 17.3% inter: 22.1% 24.4% 1.9%
# [libx264 @ 0x55ba50d60c00] i16 v,h,dc,p: 36% 38% 12% 14%
# [libx264 @ 0x55ba50d60c00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 27% 38%  2%  2%  2%  3%  2%  3%
# [libx264 @ 0x55ba50d60c00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 34% 13%  3%  4%  3%  7%  3%  5%
# [libx264 @ 0x55ba50d60c00] i8c dc,h,v,p: 40% 31% 23%  6%
# [libx264 @ 0x55ba50d60c00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55ba50d60c00] ref P L0: 74.9% 16.9%  6.5%  1.7%
# [libx264 @ 0x55ba50d60c00] ref B L0: 90.9%  8.6%  0.4%
# [libx264 @ 0x55ba50d60c00] kb/s:13323.12
