# %%
import os
import subprocess

def reencode_to_h264(directory):
    """
    Recursively walk `directory`, find all .mp4 files,
    re-encode each to H.264/AAC, and overwrite the original file.
    """
    for root, _, files in os.walk(directory):
        for fname in files:
            if not fname.lower().endswith('.mp4'):
                continue

            input_path = os.path.join(root, fname)
            tmp_path = input_path + '.tmp.mp4'

            # FFmpeg command: overwrite tmp if exists (-y)
            cmd = [
                'ffmpeg',
                '-y',                  # overwrite output without asking
                '-i', input_path,      # input file
                '-c:v', 'libx264',     # video codec
                '-preset', 'medium',   # encoding speed/quality
                '-crf', '23',          # quality
                '-c:a', 'aac',         # audio codec
                '-b:a', '128k',        # audio bitrate
                '-movflags', '+faststart',  # web optimization
                tmp_path               # temp output
            ]

            print(f"Re-encoding: {input_path}")
            try:
                subprocess.run(cmd, check=True)
                # Replace original with the new file
                os.replace(tmp_path, input_path)
                print(f"Overwritten: {input_path}")
            except subprocess.CalledProcessError as e:
                print(f"Error encoding {input_path}: {e}")
                # Clean up tmp if it exists
                if os.path.exists(tmp_path):
                    os.remove(tmp_path)

# Example usage in a Jupyter notebook cell:
reencode_to_h264('/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video')
# Out:
# Re-encoding: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/Ballroom.mp4
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/Ballroom.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:04.00, start: 0.000000, bitrate: 11526 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], 11522 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/Ballroom.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55b1db23dbc0] using SAR=1/1
# [libx264 @ 0x55b1db23dbc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55b1db23dbc0] profile High, level 5.0
# [libx264 @ 0x55b1db23dbc0] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=40 lookahead_threads=6 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/Ballroom.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2880x1280 [SAR 1:1 DAR 9:4], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x55b1db23e600] Starting second pass: moving the moov atom to the beginning of the filex
# frame=  120 fps= 74 q=-1.0 Lsize=    4459kB time=00:00:03.90 bitrate=9365.0kbits/s speed= 2.4x
# video:4456kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.050600%
# [libx264 @ 0x55b1db23dbc0] frame I:1     Avg QP:24.70  size:194262
# [libx264 @ 0x55b1db23dbc0] frame P:35    Avg QP:22.41  size: 92399
# [libx264 @ 0x55b1db23dbc0] frame B:84    Avg QP:26.16  size: 13504
# [libx264 @ 0x55b1db23dbc0] consecutive B-frames:  3.3%  6.7% 10.0% 80.0%
# [libx264 @ 0x55b1db23dbc0] mb I  I16..4: 17.0% 77.6%  5.4%
# [libx264 @ 0x55b1db23dbc0] mb P  I16..4:  3.1%  3.9%  0.4%  P16..4: 36.0% 19.6%  9.9%  0.0%  0.0%    skip:27.3%
# [libx264 @ 0x55b1db23dbc0] mb B  I16..4:  0.1%  0.1%  0.0%  B16..8: 37.8%  3.4%  0.4%  direct: 0.7%  skip:57.4%  L0:40.9% L1:49.4% BI: 9.7%
# [libx264 @ 0x55b1db23dbc0] 8x8 transform intra:59.5% inter:75.6%
# [libx264 @ 0x55b1db23dbc0] coded y,uvDC,uvAC intra: 30.5% 54.9% 11.9% inter: 12.4% 12.3% 0.9%
# [libx264 @ 0x55b1db23dbc0] i16 v,h,dc,p: 42% 31%  7% 21%
# [libx264 @ 0x55b1db23dbc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 21% 27%  2%  2%  2%  3%  2%  4%
# [libx264 @ 0x55b1db23dbc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 36% 16%  2%  4%  3%  5%  2%  4%
# [libx264 @ 0x55b1db23dbc0] i8c dc,h,v,p: 36% 27% 29%  7%
# [libx264 @ 0x55b1db23dbc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55b1db23dbc0] ref P L0: 64.5% 21.5% 11.5%  2.5%
# [libx264 @ 0x55b1db23dbc0] ref B L0: 94.4%  4.9%  0.7%
# [libx264 @ 0x55b1db23dbc0] ref B L1: 97.7%  2.3%
# [libx264 @ 0x55b1db23dbc0] kb/s:9125.05
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/flowers.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:10.00, start: 0.000000, bitrate: 156028 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 3768x828 [SAR 1:1 DAR 314:69], 156024 kb/s, 60 fps, 60 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/flowers.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/Ballroom.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/flowers.mp4
# [libx264 @ 0x55a8e31ce940] using SAR=1/1
# [libx264 @ 0x55a8e31ce940] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55a8e31ce940] profile High, level 5.1
# [libx264 @ 0x55a8e31ce940] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=26 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/flowers.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 3768x828 [SAR 1:1 DAR 314:69], q=-1--1, 60 fps, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x55a8e31d0800] Starting second pass: moving the moov atom to the beginning of the file
# frame=  600 fps= 69 q=-1.0 Lsize=   42536kB time=00:00:09.95 bitrate=35020.6kbits/s speed=1.14x
# video:42532kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.010603%
# [libx264 @ 0x55a8e31ce940] frame I:3     Avg QP:25.26  size:302922
# [libx264 @ 0x55a8e31ce940] frame P:556   Avg QP:27.74  size: 75199
# [libx264 @ 0x55a8e31ce940] frame B:41    Avg QP:30.72  size: 20299
# [libx264 @ 0x55a8e31ce940] consecutive B-frames: 86.3% 13.7%  0.0%  0.0%
# [libx264 @ 0x55a8e31ce940] mb I  I16..4: 11.1% 79.6%  9.3%
# [libx264 @ 0x55a8e31ce940] mb P  I16..4:  1.2%  5.0%  0.1%  P16..4: 38.4% 19.8% 14.1%  0.0%  0.0%    skip:21.4%
# [libx264 @ 0x55a8e31ce940] mb B  I16..4:  0.3%  0.6%  0.0%  B16..8: 50.6%  6.2%  1.6%  direct: 2.1%  skip:38.5%  L0:31.7% L1:46.0% BI:22.3%
# [libx264 @ 0x55a8e31ce940] 8x8 transform intra:79.1% inter:62.0%
# [libx264 @ 0x55a8e31ce940] coded y,uvDC,uvAC intra: 47.3% 36.3% 5.1% inter: 32.3% 15.6% 3.3%
# [libx264 @ 0x55a8e31ce940] i16 v,h,dc,p: 36% 33% 25%  5%
# [libx264 @ 0x55a8e31ce940] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 18% 54%  3%  2%  2%  2%  2%  3%
# [libx264 @ 0x55a8e31ce940] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 19% 16%  8% 10%  8% 10%  7%  8%
# [libx264 @ 0x55a8e31ce940] i8c dc,h,v,p: 57% 23% 18%  1%
# [libx264 @ 0x55a8e31ce940] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55a8e31ce940] ref P L0: 77.5% 18.3%  3.1%  1.1%
# [libx264 @ 0x55a8e31ce940] ref B L0: 95.5%  4.5%
# [libx264 @ 0x55a8e31ce940] kb/s:34841.51
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/cd.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:21.57, start: 0.000000, bitrate: 19869 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 3024x566 [SAR 1:1 DAR 1512:283], 19868 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/cd.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/flowers.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/cd.mp4
# [libx264 @ 0x560da1ca3d40] using SAR=1/1
# [libx264 @ 0x560da1ca3d40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x560da1ca3d40] profile High, level 4.0
# [libx264 @ 0x560da1ca3d40] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/cd.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 3024x566 [SAR 1:1 DAR 1512:283], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x560da1ca5c00] Starting second pass: moving the moov atom to the beginning of the file
# frame=  647 fps= 97 q=-1.0 Lsize=   18039kB time=00:00:21.46 bitrate=6883.9kbits/s speed=3.22x
# video:18034kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.028322%
# [libx264 @ 0x560da1ca3d40] frame I:3     Avg QP:22.18  size:165645
# [libx264 @ 0x560da1ca3d40] frame P:561   Avg QP:24.14  size: 30662
# [libx264 @ 0x560da1ca3d40] frame B:83    Avg QP:27.44  size:  9248
# [libx264 @ 0x560da1ca3d40] consecutive B-frames: 78.4% 13.0%  1.9%  6.8%
# [libx264 @ 0x560da1ca3d40] mb I  I16..4: 10.6% 72.5% 16.9%
# [libx264 @ 0x560da1ca3d40] mb P  I16..4:  1.4%  5.9%  0.2%  P16..4: 48.7% 14.3%  9.5%  0.0%  0.0%    skip:20.1%
# [libx264 @ 0x560da1ca3d40] mb B  I16..4:  0.6%  2.7%  0.0%  B16..8: 44.5%  3.0%  0.5%  direct: 1.1%  skip:47.6%  L0:50.5% L1:41.9% BI: 7.6%
# [libx264 @ 0x560da1ca3d40] 8x8 transform intra:77.9% inter:76.6%
# [libx264 @ 0x560da1ca3d40] coded y,uvDC,uvAC intra: 50.6% 57.1% 15.5% inter: 22.7% 26.7% 3.3%
# [libx264 @ 0x560da1ca3d40] i16 v,h,dc,p: 35% 29% 31%  6%
# [libx264 @ 0x560da1ca3d40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 20% 47%  2%  2%  1%  2%  1%  2%
# [libx264 @ 0x560da1ca3d40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 42% 21% 12%  4%  5%  4%  4%  4%  4%
# [libx264 @ 0x560da1ca3d40] i8c dc,h,v,p: 49% 24% 24%  4%
# [libx264 @ 0x560da1ca3d40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x560da1ca3d40] ref P L0: 73.0% 16.3%  8.6%  2.1%
# [libx264 @ 0x560da1ca3d40] ref B L0: 92.3%  7.2%  0.5%
# [libx264 @ 0x560da1ca3d40] ref B L1: 99.1%  0.9%
# [libx264 @ 0x560da1ca3d40] kb/s:6849.77
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/treehill.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:10.00, start: 0.000000, bitrate: 124433 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 3800x832 [SAR 1:1 DAR 475:104], 124429 kb/s, 60 fps, 60 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/treehill.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/cd.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/treehill.mp4
# [libx264 @ 0x5607610e0c00] using SAR=1/1
# [libx264 @ 0x5607610e0c00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5607610e0c00] profile High, level 5.1
# [libx264 @ 0x5607610e0c00] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=26 lookahead_threads=4 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/treehill.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 3800x832 [SAR 1:1 DAR 475:104], q=-1--1, 60 fps, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x5607610e2ac0] Starting second pass: moving the moov atom to the beginning of the file
# frame=  600 fps= 70 q=-1.0 Lsize=   34944kB time=00:00:09.95 bitrate=28770.2kbits/s speed=1.17x
# video:34940kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013198%
# [libx264 @ 0x5607610e0c00] frame I:3     Avg QP:24.58  size:254249
# [libx264 @ 0x5607610e0c00] frame P:553   Avg QP:26.76  size: 61597
# [libx264 @ 0x5607610e0c00] frame B:44    Avg QP:29.57  size: 21638
# [libx264 @ 0x5607610e0c00] consecutive B-frames: 86.0% 12.3%  1.0%  0.7%
# [libx264 @ 0x5607610e0c00] mb I  I16..4: 12.3% 77.4% 10.3%
# [libx264 @ 0x5607610e0c00] mb P  I16..4:  1.9%  5.1%  0.2%  P16..4: 37.5% 14.7%  8.6%  0.0%  0.0%    skip:32.0%
# [libx264 @ 0x5607610e0c00] mb B  I16..4:  0.4%  0.6%  0.0%  B16..8: 44.6%  4.8%  1.2%  direct: 3.7%  skip:44.6%  L0:41.7% L1:47.4% BI:10.9%
# [libx264 @ 0x5607610e0c00] 8x8 transform intra:70.4% inter:62.5%
# [libx264 @ 0x5607610e0c00] coded y,uvDC,uvAC intra: 31.9% 24.1% 2.4% inter: 24.8% 7.1% 0.1%
# [libx264 @ 0x5607610e0c00] i16 v,h,dc,p: 51% 30% 15%  4%
# [libx264 @ 0x5607610e0c00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 19% 54%  2%  1%  1%  2%  1%  2%
# [libx264 @ 0x5607610e0c00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 17% 22%  6%  8%  7%  8%  5%  7%
# [libx264 @ 0x5607610e0c00] i8c dc,h,v,p: 64% 19% 16%  1%
# [libx264 @ 0x5607610e0c00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5607610e0c00] ref P L0: 74.6% 18.3%  5.5%  1.6%
# [libx264 @ 0x5607610e0c00] ref B L0: 92.6%  7.2%  0.2%
# [libx264 @ 0x5607610e0c00] ref B L1: 99.9%  0.1%
# [libx264 @ 0x5607610e0c00] kb/s:28622.16
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/lab.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:21.00, start: 0.000000, bitrate: 20199 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 3024x566 [SAR 1:1 DAR 1512:283], 20198 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/lab.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/treehill.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/lab.mp4
# [libx264 @ 0x559071cbab40] using SAR=1/1
# [libx264 @ 0x559071cbab40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x559071cbab40] profile High, level 4.0
# [libx264 @ 0x559071cbab40] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/lab.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 3024x566 [SAR 1:1 DAR 1512:283], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x559071cbca00] Starting second pass: moving the moov atom to the beginning of the file
# frame=  630 fps=100 q=-1.0 Lsize=   17666kB time=00:00:20.90 bitrate=6924.4kbits/s speed=3.32x
# video:17660kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.034716%
# [libx264 @ 0x559071cbab40] frame I:3     Avg QP:22.08  size:149854
# [libx264 @ 0x559071cbab40] frame P:438   Avg QP:24.06  size: 35815
# [libx264 @ 0x559071cbab40] frame B:189   Avg QP:27.45  size: 10298
# [libx264 @ 0x559071cbab40] consecutive B-frames: 54.9% 13.0%  6.7% 25.4%
# [libx264 @ 0x559071cbab40] mb I  I16..4: 12.6% 73.1% 14.3%
# [libx264 @ 0x559071cbab40] mb P  I16..4:  2.2%  6.9%  0.2%  P16..4: 44.7% 16.8% 10.3%  0.0%  0.0%    skip:18.9%
# [libx264 @ 0x559071cbab40] mb B  I16..4:  0.6%  2.5%  0.0%  B16..8: 45.9%  3.9%  0.6%  direct: 1.4%  skip:45.1%  L0:45.8% L1:42.5% BI:11.7%
# [libx264 @ 0x559071cbab40] 8x8 transform intra:75.1% inter:72.6%
# [libx264 @ 0x559071cbab40] coded y,uvDC,uvAC intra: 43.8% 36.4% 5.4% inter: 23.1% 14.3% 1.5%
# [libx264 @ 0x559071cbab40] i16 v,h,dc,p: 33% 34% 25%  8%
# [libx264 @ 0x559071cbab40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 24% 45%  2%  2%  1%  3%  1%  3%
# [libx264 @ 0x559071cbab40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 25% 13%  3%  9%  3% 11%  3%  5%
# [libx264 @ 0x559071cbab40] i8c dc,h,v,p: 57% 22% 20%  1%
# [libx264 @ 0x559071cbab40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x559071cbab40] ref P L0: 73.2% 17.2%  7.7%  2.0%
# [libx264 @ 0x559071cbab40] ref B L0: 93.5%  5.8%  0.6%
# [libx264 @ 0x559071cbab40] ref B L1: 98.3%  1.7%
# [libx264 @ 0x559071cbab40] kb/s:6888.75
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/counter.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:10.00, start: 0.000000, bitrate: 55626 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 4674x1038 [SAR 1:1 DAR 779:173], 55622 kb/s, 60 fps, 60 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/counter.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/lab.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/counter.mp4
# [libx264 @ 0x559b141ce700] using SAR=1/1
# [libx264 @ 0x559b141ce700] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x559b141ce700] profile High, level 5.2
# [libx264 @ 0x559b141ce700] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=32 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/counter.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 4674x1038 [SAR 1:1 DAR 779:173], q=-1--1, 60 fps, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x559b141d05c0] Starting second pass: moving the moov atom to the beginning of the filex
# frame=  600 fps= 58 q=-1.0 Lsize=   24681kB time=00:00:09.95 bitrate=20320.0kbits/s speed=0.959x
# video:24676kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.018834%
# [libx264 @ 0x559b141ce700] frame I:3     Avg QP:23.27  size:193240
# [libx264 @ 0x559b141ce700] frame P:548   Avg QP:24.93  size: 43556
# [libx264 @ 0x559b141ce700] frame B:49    Avg QP:27.51  size: 16718
# [libx264 @ 0x559b141ce700] consecutive B-frames: 83.7% 16.3%  0.0%  0.0%
# [libx264 @ 0x559b141ce700] mb I  I16..4: 18.4% 74.9%  6.7%
# [libx264 @ 0x559b141ce700] mb P  I16..4:  2.6%  8.8%  0.1%  P16..4: 43.1%  6.8%  2.9%  0.0%  0.0%    skip:35.7%
# [libx264 @ 0x559b141ce700] mb B  I16..4:  0.7%  1.2%  0.0%  B16..8: 40.9%  1.7%  0.2%  direct: 1.6%  skip:53.7%  L0:50.2% L1:47.0% BI: 2.9%
# [libx264 @ 0x559b141ce700] 8x8 transform intra:76.3% inter:85.7%
# [libx264 @ 0x559b141ce700] coded y,uvDC,uvAC intra: 30.1% 35.8% 3.0% inter: 12.6% 11.6% 0.5%
# [libx264 @ 0x559b141ce700] i16 v,h,dc,p: 46% 27% 19%  8%
# [libx264 @ 0x559b141ce700] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 19% 49%  1%  1%  1%  1%  1%  1%
# [libx264 @ 0x559b141ce700] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 17% 20%  4%  8%  7%  7%  4%  4%
# [libx264 @ 0x559b141ce700] i8c dc,h,v,p: 56% 21% 22%  2%
# [libx264 @ 0x559b141ce700] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x559b141ce700] ref P L0: 77.5% 16.0%  5.2%  1.2%
# [libx264 @ 0x559b141ce700] ref B L0: 93.4%  6.6%
# [libx264 @ 0x559b141ce700] kb/s:20214.15
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/guitar.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:17.60, start: 0.000000, bitrate: 15208 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 3024x566 [SAR 1:1 DAR 1512:283], 15206 kb/s, 30 fps, 30 tbr, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/guitar.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/counter.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/guitar.mp4
# [libx264 @ 0x563a985e8500] using SAR=1/1
# [libx264 @ 0x563a985e8500] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x563a985e8500] profile High, level 4.0
# [libx264 @ 0x563a985e8500] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=18 lookahead_threads=3 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/guitar.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 3024x566 [SAR 1:1 DAR 1512:283], q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# [mp4 @ 0x563a985ea3c0] Starting second pass: moving the moov atom to the beginning of the file
# frame=  528 fps=130 q=-1.0 Lsize=    9036kB time=00:00:17.50 bitrate=4229.8kbits/s speed=4.31x
# video:9029kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.071230%
# [libx264 @ 0x563a985e8500] frame I:3     Avg QP:19.79  size:146194
# [libx264 @ 0x563a985e8500] frame P:209   Avg QP:22.21  size: 31562
# [libx264 @ 0x563a985e8500] frame B:316   Avg QP:25.67  size:  6995
# [libx264 @ 0x563a985e8500] consecutive B-frames: 17.6%  3.8% 11.9% 66.7%
# [libx264 @ 0x563a985e8500] mb I  I16..4: 16.1% 68.8% 15.1%
# [libx264 @ 0x563a985e8500] mb P  I16..4:  3.3%  9.7%  0.2%  P16..4: 44.2% 12.4%  7.4%  0.0%  0.0%    skip:22.7%
# [libx264 @ 0x563a985e8500] mb B  I16..4:  0.5%  1.7%  0.0%  B16..8: 45.1%  2.4%  0.2%  direct: 0.8%  skip:49.2%  L0:48.7% L1:46.8% BI: 4.5%
# [libx264 @ 0x563a985e8500] 8x8 transform intra:73.8% inter:76.9%
# [libx264 @ 0x563a985e8500] coded y,uvDC,uvAC intra: 32.1% 35.6% 5.8% inter: 10.6% 11.3% 1.7%
# [libx264 @ 0x563a985e8500] i16 v,h,dc,p: 36% 31% 23%  9%
# [libx264 @ 0x563a985e8500] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 20% 49%  2%  1%  1%  2%  1%  2%
# [libx264 @ 0x563a985e8500] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 22% 17%  5%  5%  5%  7%  4%  5%
# [libx264 @ 0x563a985e8500] i8c dc,h,v,p: 54% 25% 20%  2%
# [libx264 @ 0x563a985e8500] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x563a985e8500] ref P L0: 68.2% 14.2% 14.0%  3.6%
# [libx264 @ 0x563a985e8500] ref B L0: 90.2%  8.5%  1.3%
# [libx264 @ 0x563a985e8500] ref B L1: 95.7%  4.3%
# [libx264 @ 0x563a985e8500] kb/s:4202.46
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/train.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:10.00, start: 0.000000, bitrate: 51461 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 2940x544 [SAR 1:1 DAR 735:136], 51457 kb/s, 60 fps, 60 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/train.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55740ae3d300] using SAR=1/1
# [libx264 @ 0x55740ae3d300] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55740ae3d300] profile High, level 4.2
# [libx264 @ 0x55740ae3d300] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=17 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/train.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 2940x544 [SAR 1:1 DAR 735:136], q=-1--1, 60 fps, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# Overwritten: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/guitar.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/train.mp4
# [mp4 @ 0x55740ae3f1c0] Starting second pass: moving the moov atom to the beginning of the file
# frame=  600 fps= 96 q=-1.0 Lsize=   15282kB time=00:00:09.95 bitrate=12581.7kbits/s speed= 1.6x
# video:15277kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.029922%
# [libx264 @ 0x55740ae3d300] frame I:4     Avg QP:23.71  size: 68812
# [libx264 @ 0x55740ae3d300] frame P:528   Avg QP:27.04  size: 27465
# [libx264 @ 0x55740ae3d300] frame B:68    Avg QP:29.07  size: 12740
# [libx264 @ 0x55740ae3d300] consecutive B-frames: 80.7% 11.3%  4.0%  4.0%
# [libx264 @ 0x55740ae3d300] mb I  I16..4: 21.4% 71.3%  7.3%
# [libx264 @ 0x55740ae3d300] mb P  I16..4:  3.8% 11.0%  0.4%  P16..4: 44.0% 14.2%  6.7%  0.0%  0.0%    skip:19.8%
# [libx264 @ 0x55740ae3d300] mb B  I16..4:  4.0%  6.0%  0.1%  B16..8: 41.7%  6.1%  1.0%  direct: 2.9%  skip:38.2%  L0:45.2% L1:44.3% BI:10.5%
# [libx264 @ 0x55740ae3d300] 8x8 transform intra:71.0% inter:74.1%
# [libx264 @ 0x55740ae3d300] coded y,uvDC,uvAC intra: 37.8% 40.0% 3.3% inter: 26.2% 14.9% 0.7%
# [libx264 @ 0x55740ae3d300] i16 v,h,dc,p: 36% 32% 17% 14%
# [libx264 @ 0x55740ae3d300] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 22% 42%  2%  1%  1%  2%  1%  2%
# [libx264 @ 0x55740ae3d300] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 24% 14%  4%  5%  5%  7%  4%  4%
# [libx264 @ 0x55740ae3d300] i8c dc,h,v,p: 56% 22% 20%  2%
# [libx264 @ 0x55740ae3d300] Weighted P-Frames: Y:1.5% UV:0.8%
# [libx264 @ 0x55740ae3d300] ref P L0: 70.6% 21.9%  5.8%  1.7%  0.0%
# [libx264 @ 0x55740ae3d300] ref B L0: 91.1%  8.0%  0.9%
# [libx264 @ 0x55740ae3d300] ref B L1: 98.6%  1.4%
# [libx264 @ 0x55740ae3d300] kb/s:12514.58
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/kitchen.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf59.27.100
#   Duration: 00:00:10.00, start: 0.000000, bitrate: 74069 kb/s
#     Stream #0:0(und): Video: mpeg4 (Simple Profile) (mp4v / 0x7634706D), yuv420p, 4674x1038 [SAR 1:1 DAR 779:173], 74066 kb/s, 60 fps, 60 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Codec AVOption b (set bitrate (in bits/s)) specified for output file #0 (/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/kitchen.mp4.tmp.mp4) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (mpeg4 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# Overwritten: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/train.mp4
# Re-encoding: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/kitchen.mp4
# [libx264 @ 0x562aa4304940] using SAR=1/1
# [libx264 @ 0x562aa4304940] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x562aa4304940] profile High, level 5.2
# [libx264 @ 0x562aa4304940] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=32 lookahead_threads=5 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/kitchen.mp4.tmp.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 4674x1038 [SAR 1:1 DAR 779:173], q=-1--1, 60 fps, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  572 fps= 62 q=31.0 size=   22016kB time=00:00:08.21 bitrate=21949.8kbits/s speed=0.89x     5x
# Overwritten: /home/hoangchuongnguyen/Desktop/Neurips_2025/website/IBGS/video/kitchen.mp4
# [mp4 @ 0x562aa4306800] Starting second pass: moving the moov atom to the beginning of the file
# frame=  600 fps= 57 q=-1.0 Lsize=   26557kB time=00:00:09.95 bitrate=21864.4kbits/s speed=0.949x
# video:26552kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.016753%
# [libx264 @ 0x562aa4304940] frame I:3     Avg QP:23.16  size:302692
# [libx264 @ 0x562aa4304940] frame P:545   Avg QP:25.40  size: 46224
# [libx264 @ 0x562aa4304940] frame B:52    Avg QP:28.80  size: 20932
# [libx264 @ 0x562aa4304940] consecutive B-frames: 85.2%  9.0%  2.5%  3.3%
# [libx264 @ 0x562aa4304940] mb I  I16..4: 14.0% 79.2%  6.8%
# [libx264 @ 0x562aa4304940] mb P  I16..4:  1.7%  6.8%  0.1%  P16..4: 42.9%  9.7%  4.9%  0.0%  0.0%    skip:33.8%
# [libx264 @ 0x562aa4304940] mb B  I16..4:  0.7%  1.6%  0.0%  B16..8: 45.7%  2.1%  0.2%  direct: 1.4%  skip:48.1%  L0:49.3% L1:45.6% BI: 5.1%
# [libx264 @ 0x562aa4304940] 8x8 transform intra:78.7% inter:83.7%
# [libx264 @ 0x562aa4304940] coded y,uvDC,uvAC intra: 39.2% 35.1% 3.6% inter: 15.4% 16.7% 1.8%
# [libx264 @ 0x562aa4304940] i16 v,h,dc,p: 46% 29% 19%  6%
# [libx264 @ 0x562aa4304940] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 19% 49%  2%  1%  1%  1%  2%  1%
# [libx264 @ 0x562aa4304940] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 28% 13%  5%  6%  5%  7%  7%  6%
# [libx264 @ 0x562aa4304940] i8c dc,h,v,p: 56% 23% 20%  1%
# [libx264 @ 0x562aa4304940] Weighted P-Frames: Y:0.2% UV:0.2%
# [libx264 @ 0x562aa4304940] ref P L0: 77.4% 16.9%  4.8%  1.0%  0.0%
# [libx264 @ 0x562aa4304940] ref B L0: 93.9%  5.8%  0.3%
# [libx264 @ 0x562aa4304940] ref B L1: 99.4%  0.6%
# [libx264 @ 0x562aa4304940] kb/s:21751.05
